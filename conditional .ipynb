# %%
Age = 5
print(Age)
# Out:
# 5

# %%
Price=input("Please enter the price: ")
Price=int(Price)
print(Price+Price*14/100)
# Out:
# Please enter the price: 100
# 114.0

# %%
num=5
if num>3 :
  print("great")
# Out:
# great

# %%
num=5
if num>7 :
  print("great")
print("not great")
# Out:
# not great

# %%
num=5
if num>7 :
  print("great")
else:
  print("good")
# Out:
# good

# %%
num=5
if num>7 :
  print("great")
elif num<7:
  print("very good")
else:
  print("good")
# Out:
# very good

# %%
password="0000"
balance=3000
while True:
  Passsword=input("Enter your password:")
  while(password!=Passsword):
    Passsword=input("Enter your password again:")
  print("Choose operation press 1 to check balance")
  option=int(input("enter option"))
  if   option==1:
    print("your balance is" ,balance)
  else:
    print("invalid option")
# Out:
# Choose operation press 1 to check balance
# your balance is 3000
