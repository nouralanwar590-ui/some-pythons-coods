# %%
import datetime

datetime.datetime.now()
# Out:
# datetime.datetime(2025, 8, 26, 10, 52, 43, 831955)

# %%
import random

num=random.randint(1, 13)
print(num)
# Out:
# 5

# %%
import math
print(math.sqrt(9))
# Out:
# 3.0

# %%
import mymath
mymath.min(7,76)
# Out:
# 7
